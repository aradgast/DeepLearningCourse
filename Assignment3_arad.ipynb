# %% [markdown]
# <a href="https://colab.research.google.com/github/aradgast/DeepLearningCourse/blob/main/Assignment3_arad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3: Image Classification
#
# **Assignment Responsible**: Natalie Lang.
#
# In this assignment, we will build a convolutional neural network that can predict
# whether two shoes are from the **same pair** or from two **different pairs**.
# This kind of application can have real-world applications: for example to help
# people who are visually impaired to have more independence.
#
# We will explore two convolutional architectures. While we will give you starter
# code to help make data processing a bit easier, in this assignment you have a chance to build your neural network all by yourself.
#
# You may modify the starter code as you see fit, including changing the signatures of
# functions and adding/removing helper functions. However, please make sure that we can understand what you are doing and why.

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# ## Question 1. Data (20%)
#
# Download the data from https://www.dropbox.com/s/6gdcpmfddojrl8o/data.rar?dl=0.
#
# Unzip the file. There are three
# main folders: `train`, `test_w` and `test_m`. Data in `train` will be used for
# training and validation, and the data in the other folders will be used for testing.
# This is so that the entire class will have the same test sets. The dataset is comprised of triplets of pairs, where each such triplet of image pairs was taken in a similar setting (by the same person).
#
# We've separated `test_w` and `test_m` so that we can track our model performance
# for women's shoes and men's shoes separately. Each of the test sets contain images of either exclusively men's shoes or women's
# shoes.
#
# Upload this data to Google Colab.
# Then, mount Google Drive from your Google Colab notebook:

# %%
############## DELETE IT ###############################
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import glob
folders = ['train', 
           'test_w',
           'test_m']
for folder in folders:
  path = f"/content/gdrive/My Drive/Data/assigment3/data/{folder}/*" # TODO - UPDATE ME!
  images = {}
  for file in glob.glob(path):
      filename = file.split("/")[-1]   # get the name of the .jpg file
      img = plt.imread(file)           # read the image as a numpy array
      images[filename] = img[:, :, :3] # remove the alpha channel

  with open(f'saved_images_{folder}.pkl', 'wb') as f:
      pickle.dump(images, f)

# %%
from collections import OrderedDict
def order_data(images_dict):
  num_of_users = len(list(images_dict.keys()))//6
  data = np.zeros(shape=(num_of_users, 3, 2, 224,224,3))
  images_dict = OrderedDict(sorted(images_dict.items()))
  current_idx = int(list(images_dict.keys())[0].split('_')[0][1:])
  idx = 0
  for k, v in images_dict.items():
    idx_user = int(k.split('_')[0][1:])
    if idx_user != current_idx:
      current_idx = idx_user
      idx += 1
    idx_triplet = int(k.split('_')[1]) -1
    idx_left_right = int(k.split('_')[2] == 'right')
    data[idx, idx_triplet, idx_left_right, :,:,:] = v/255-0.5
  return data


for folder in folders:
  path = f'/content/gdrive/My Drive/Data/assigment3/saved_images_{folder}.pkl'
  with open(path, 'rb') as f:
    images = pickle.load(f)

  orderd_images = order_data(images)
  print(f'{folder} size : {orderd_images.shape}')
  if folder == 'train':
    path = '/content/gdrive/My Drive/Data/assigment3/train_data_array.pkl'
    with open(path, 'wb') as f:
      pickle.dump(orderd_images[:int(len(order_data)*0.8)], f)
    path = '/content/gdrive/My Drive/Data/assigment3/valid_data_array.pkl'
    with open(path, 'wb') as f:
      pickle.dump(orderd_images[int(len(order_data)*0.8):], f)
  else:
    path = '/content/gdrive/My Drive/Data/assigment3/{folder}_data_array.pkl'
    with open(path, 'wb') as f:
      pickle.dump(orderd_images, f)
# Out:
# (10, 3, 2, 224, 224, 3)

# %% [markdown]
# After you have done so, read this entire section
# before proceeding. There are right and wrong ways of
# processing this data. If you don't make the correct choices, you may find
# yourself needing to start over.
# Many machine learning projects fail because of the lack of care taken during
# the data processing stage.

# %% [markdown]
# ### Part (a) -- 8%
#
# Load the training and test data, and separate your training data into training and validation.
# Create the numpy arrays `train_data`, `valid_data`, `test_w` and `test_m`, all of which should
# be of shape `[*, 3, 2, 224, 224, 3]`. The dimensions of these numpy arrays are as follows:
#
# - `*` - the number of triplets allocated to train, valid, or test
# - `3` - the 3 pairs of shoe images in that triplet
# - `2` - the left/right shoes
# - `224` - the height of each image
# - `224` - the width of each image
# - `3` - the colour channels
#
# So, the item `train_data[4,0,0,:,:,:]` should give us the left shoe of the first image of the fifth person.The item `train_data[4,0,1,:,:,:]`  should be the right shoe in the same pair.
# The item `train_data[4,1,1,:,:,:]`  should be the right shoe in a different pair of that same person.
#
# When you first load the images using (for example) `plt.imread`, you may see a numpy array of shape
# `[224, 224, 4]` instead of `[224, 224, 3]`. That last channel is what's called the alpha channel for transparent
# pixels, and should be removed.
# The pixel intensities are stored as an integer between 0 and 255.
# Make sure you normlize your images, namely, divide the intensities by 255 so that you have floating-point values between 0 and 1. Then, subtract 0.5
# so that the elements of `train_data`, `valid_data` and `test_data` are between -0.5 and 0.5.
# **Note that this step actually makes a huge difference in training!**
#
# This function might take a while to run; it can takes several minutes to just
# load the files from Google Drive.  If you want to avoid
# running this code multiple times, you can save
# your numpy arrays and load it later:
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.save.html

# %%
import pickle
#for Arad
if True:
  # path = r'C:\Users\aradg\OneDrive - post.bgu.ac.il\data\deep_learnning_data\assigment3'
  path = r'/content/gdrive/My Drive/Data/assigment3/'
else:
# for Yhonatan:
  path = '/Users/yhonatangayer/Library/CloudStorage/OneDrive-post.bgu.ac.il/BGU/Semster 7/Deep Learning/EX3/data/'
with open(path+'train_data_array.pkl', 'rb') as f:
    train_data = pickle.load(f)
with open(path + 'valid_data_array.pkl', 'rb') as f:
    valid_data = pickle.load(f)
with open(path + 'test_w_array.pkl', 'rb') as f:
    test_w = pickle.load(f)
with open(path + 'test_m_array.pkl', 'rb') as f:
    test_m = pickle.load(f)

# %%
# Run this code, include the image in your PDF submission
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(np.add(train_data[4,0,0,:,:,:],0.5)) # left shoe of first pair submitted by 5th student
plt.figure()
plt.imshow(np.add(train_data[4,0,1,:,:,:],0.5)) # right shoe of first pair submitted by 5th student
plt.figure()
plt.imshow(np.add(train_data[4,1,1,:,:,:],0.5)) # right shoe of second pair submitted by 5th student

# %% [markdown]
# ### Part (b) -- 4%
#
# Since we want to train a model that determines whether two shoes come from the **same**
# pair or **different** pairs, we need to create some labelled training data.
# Our model will take in an image, either consisting of two shoes from the **same pair**
# or from **different pairs**. So, we'll need to generate some *positive examples* with
# images containing two shoes that *are* from the same pair, and some *negative examples* where
# images containing two shoes that *are not* from the same pair.
# We'll generate the *positive examples* in this part, and the *negative examples* in the next part.
#
# Write a function `generate_same_pair()` that takes one of the data sets that you produced
# in part (a), and generates a numpy array where each pair of shoes in the data set is
# concatenated together. In particular, we'll be concatenating together images of left
# and right shoes along the **height** axis. Your function `generate_same_pair` should
# return a  numpy array of shape `[*, 448, 224, 3]`.
#
# While at this stage we are working with numpy arrays, later on, we will need to convert this numpy array into a PyTorch tensor with shape
# `[*, 3, 448, 224]`. For now, we'll keep the RGB channel as the last dimension since
# that's what `plt.imshow` requires.

# %%
def generate_same_pair(data_set):
  res = np.empty((np.shape(data_set)[0] * np.shape(data_set)[1], 448,224,3))
  for i in range(np.shape(data_set)[0]):
    for j in range(np.shape(data_set)[1]):
      tmp_left = np.array(data_set[i,j,0,:,:,:])
      tmp_right = np.array(data_set[i,j,1,:,:,:])
      tmp_merged = np.concatenate((tmp_left, tmp_right), axis=0)
      res[(i+1)*(j+1)-1,:,:,:] = tmp_merged
  return res

# Run this code, include the result with your PDF submission
print(train_data.shape) # if this is [N, 3, 2, 224, 224, 3]
print(generate_same_pair(train_data).shape) # should be [N*3, 448, 224, 3]
plt.imshow(generate_same_pair(np.add(train_data,0.5))[0]) # should show 2 shoes from the same pair
# Out:
# (89, 3, 2, 224, 224, 3)
# (267, 448, 224, 3)

# %% [markdown]
# ### Part (c) -- 4%
#
# Write a function `generate_different_pair()` that takes one of the data sets that
# you produced in part (a), and generates a numpy array in the same shape as part (b).
# However, each image will contain 2 shoes from a **different** pair, but submitted
# by the **same student**. Do this by jumbling the 3 pairs of shoes submitted by
# each student.
#
# Theoretically, for each person (triplet of pairs), there are 6 different combinations
# of "wrong pairs" that we could produce. To keep our data set *balanced*, we will
# only produce **three** combinations of wrong pairs per unique person.
# In other words,`generate_same_pairs` and `generate_different_pairs` should
# return the same number of training examples.

# %%
def generate_different_pair(data_set):
  res = np.empty((np.shape(data_set)[0] * np.shape(data_set)[1], 448,224,3))
  for i in range(np.shape(data_set)[0]):
    tmp_left0  = np.array(data_set[i,0,0,:,:,:])
    tmp_left1  = np.array(data_set[i,1,0,:,:,:])
    tmp_left2  = np.array(data_set[i,2,0,:,:,:])
    tmp_right0 = np.array(data_set[i,0,1,:,:,:])
    tmp_right1 = np.array(data_set[i,1,1,:,:,:])
    tmp_right2 = np.array(data_set[i,2,1,:,:,:])
    tmp_merged0 = np.concatenate((tmp_left0, tmp_right1), axis=0)
    tmp_merged1 = np.concatenate((tmp_left1, tmp_right2), axis=0)
    tmp_merged2 = np.concatenate((tmp_left2, tmp_right0), axis=0)
    res[(i+1)*(0+1)-1,:,:,:] = tmp_merged0
    res[(i+1)*(1+1)-1,:,:,:] = tmp_merged1
    res[(i+1)*(2+1)-1,:,:,:] = tmp_merged2

  return res
# Run this code, include the result with your PDF submission
print(train_data.shape) # if this is [N, 3, 2, 224, 224, 3]
print(generate_different_pair(train_data).shape) # should be [N*3, 448, 224, 3]
plt.imshow(np.add(generate_different_pair(train_data)[0],0.5)) # should show 2 shoes from different pairs
# Out:
# (89, 3, 2, 224, 224, 3)
# (267, 448, 224, 3)

# %% [markdown]
# ### Part (d) -- 2%
#
# Why do we insist that the different pairs of shoes still come from the same
# person?  (Hint: what else do images from the same person have in common?)

# %% [markdown]
# If we use the different pairs from different persons we will get more differences in the images due to different scene
# different background, lighting,distance from camera, etc.
# also by using the same person we get the same shoe size even though the shoes aren't match.
# When we are using different pairs from the same person we give the model more similar futures to relay on.
# so in each image of different pairs, the model will have to learn the differences in the shoe details and won't be able to relay on other differences in the scene or in the shoe size.
# that way we make the model accurate to do its purpose as we want.

# %% [markdown]
# ### Part (e) -- 2%
#
# Why is it important that our data set be *balanced*? In other words suppose we created
# a data set where 99% of the images are of shoes that are *not* from the same pair, and
# 1% of the images are shoes that *are* from the same pair. Why could this be a problem?

# %% [markdown]
# It is important that our data will be balanced, because when we train a NN model, the model also taking in consider the apriori-cal probability that each image will be from the same pair or from a different pair.
# that means that if we will train the model on a data set where 99% of the images are of shoes that are not from the same pair, we will get a NN that influenced by an un i.i.d data set.
# for our task we want the NN to be able to guess  an unbiased guess if the shoes are from the same pair or not, the best way to make sure that our guess won't be biased is by making sure that our train data is balanced, that means that it is i.i.d distributed.

# %% [markdown]
# ## Question 2. Convolutional Neural Networks (25%)
#
# Before starting this question, we recommend reviewing the lecture and its associated example notebook on CNNs.
#
# In this section, we will build two CNN models in PyTorch.
#
# ### Part (a) -- 9%
#
# Implement a CNN model in PyTorch called `CNN` that will take images of size
# $3 \times 448 \times 224$, and classify whether the images contain shoes from
# the same pair or from different pairs.
#
# The model should contain the following layers:
#
# - A convolution layer that takes in 3 channels, and outputs $n$ channels.
# - A $2 \times 2$ downsampling (either using a strided convolution in the previous step, or max pooling)
# - A second convolution layer that takes in $n$ channels, and outputs $2\cdot n$ channels.
# - A $2 \times 2$ downsampling (either using a strided convolution in the previous step, or max pooling)
# - A third convolution layer that takes in $2\cdot n$ channels, and outputs $4\cdot n$ channels.
# - A $2 \times 2$ downsampling (either using a strided convolution in the previous step, or max pooling)
# - A fourth convolution layer that takes in $4\cdot n$ channels, and outputs $8\cdot n$ channels.
# - A $2 \times 2$ downsampling (either using a strided convolution in the previous step, or max pooling)
# - A fully-connected layer with 100 hidden units
# - A fully-connected layer with 2 hidden units
#
# Make the variable $n$ a parameter of your CNN. You can use either $3 \times 3$ or $5 \times 5$
# convolutions kernels. Set your padding to be `(kernel_size - 1) / 2` so that your feature maps
# have an even height/width.
#
# Note that we are omitting in our description certain steps that practitioners will typically not mention,
# like ReLU activations and reshaping operations. Use the example presented in class to figure out where they are.

# %%
class CNN(nn.Module):
    def __init__(self, n=4, kernel_size = 3):
        super(CNN, self).__init__()
        self.n = n
        self.kernel_size = kernel_size
        self.maxpool = nn.MaxPool2d(2)
        self.conv1 = nn.Conv2d(in_channels=3,
                               out_channels=n,
                               kernel_size=kernel_size,
                               padding = (kernel_size-1)//2)
        self.conv2 = nn.Conv2d(in_channels=n,
                               out_channels=2 * n,
                               kernel_size=kernel_size,
                               padding = (kernel_size-1)//2)
        self.conv3 = nn.Conv2d(in_channels=2 * n,
                               out_channels=4 * n,
                               kernel_size=kernel_size,
                               padding = (kernel_size-1)//2)
        self.conv4 = nn.Conv2d(in_channels=4 * n,
                               out_channels=8 * n,
                               kernel_size=kernel_size,
                               padding = (kernel_size-1)//2)
        
        self.lin1 = nn.Linear(28*14*8*n, 100)
        self.lin2 = nn.Linear(100, 2)
        self.relu = nn.ReLU()

    def forward(self, x, verbose=False):
        
        x = self.conv1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x = self.conv2(x)
        x = self.relu(x)
        x = self.maxpool(x)


        x = self.conv3(x)
        x = self.relu(x)
        x = self.maxpool(x)


        x = self.conv4(x)
        x = self.relu(x)
        x = self.maxpool(x)


        x = x.reshape(-1,28*14*8*self.n)                  #, self.n_feature*8)
        x = self.lin1(x)
        x = self.relu(x)
        x = self.lin2(x)          # size of x is [392,2] , IT SHOULD BE [1,2]!! I THINK
        return x

# %% [markdown]
# ### Part (b) -- 8%
#
# Implement a CNN model in PyTorch called `CNNChannel` that contains the same layers as
# in the Part (a), but with one crucial difference: instead of starting with an image
# of shape $3 \times 448 \times 224$, we will first manipulate the image so that the
# left and right shoes images are concatenated along the **channel** dimension.
#
# <img src="https://drive.google.com/uc?id=1B59VE43X-6Dw3ag-9Ndn6vPEzbnFem8K" width="400px" />
#
#
# Complete the manipulation in the `forward()` method (by slicing and using
# the function `torch.cat`). The input to the first convolutional layer
# should have 6 channels instead of 3 (input shape $6 \times 224 \times 224$).
#
# Use the same hyperparameter choices as you did in part (a), e.g. for the kernel size,
# choice of downsampling, and other choices.

# %%
class CNNChannel(nn.Module):
    def __init__(self, n=4, kernel_size = 3):
        super(CNNChannel, self).__init__()
        self.n = n
        self.kernel_size = kernel_size
        self.maxpool = nn.MaxPool2d(2)
        self.conv1 = nn.Conv2d(in_channels= 6,
                               out_channels= n,
                               kernel_size=kernel_size,
                               padding = (kernel_size-1)//2)
        self.conv2 = nn.Conv2d(in_channels= n,
                               out_channels=2 * n,
                               kernel_size=kernel_size,
                               padding = (kernel_size-1)//2)
        self.conv3 = nn.Conv2d(in_channels=2 * n,
                               out_channels=4 * n,
                               kernel_size=kernel_size,
                               padding = (kernel_size-1)//2)
        self.conv4 = nn.Conv2d(in_channels=4 * n,
                               out_channels=8 * n,
                               kernel_size=kernel_size,
                               padding = (kernel_size-1)//2)
        
        self.lin1 = nn.Linear(14*14*8*self.n, 100)
        self.lin2 = nn.Linear(100, 2)
        self.relu = nn.ReLU()
    
    def forward(self, x, verbose=False):
        x = torch.cat((x[:,:,:,:224], x[:,:,:,224:]),1)
        x = self.conv1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x = self.conv2(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x = self.conv3(x)
        x = self.relu(x)
        x = self.maxpool(x)        

        x = self.conv4(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x = x.reshape(-1,14*14*8*self.n)                  #, self.n_feature*8)
        x = self.lin1(x)
        x = self.relu(x)
        x = self.lin2(x)          # size of x is [392,2] , IT SHOULD BE [1,2]!! I THINK
        return x

# %% [markdown]
# ## Part (c) -- 4%
#
# The two models are quite similar, and should have almost the same number of parameters.
# However, one of these models will perform better, showing that architecture choices **do**
# matter in machine learning. Explain why one of these models performs better.

# %% [markdown]
# **Write your explanation here:**
#
# In the first case, two images of shoes are count as one, for that reason the CNN will apply filters on the two images as if they were one image.it can cause some of the outcomes of the filters will have no reasonable meaning.
# In class, we leaned that part of the reason that CNN works well on images is due to the locality and stationary, in the first case those qualities are not preserved and for that reason we can assume that CNN won't make good performance on them.
#
# The second case we will apply filters on each image separately, so we will avoid of the nonsense outcomes we had in the first CNN we built.
# we also make sure by separating the images that the stationary and locality of the images will preserve.
#
# we expect better outcomes using the 2'nd CNN we built for the reasons we explained.

# %% [markdown]
# ## Part (d) -- 4%
#
# The function `get_accuracy` is written for you. You may need to modify this
# function depending on how you set up your model and training.
#
# Unlike in the previous assignment, her we will separately compute the model accuracy on the
# positive and negative samples.  Explain why we may wish to track the false positives and false negatives separately.

# %% [markdown]
# **Write your explanation here:**
#
# in this case, its important to track the the false positive and false negative separately, because we want to see and avoid a NN that might lean toward a certain conclusion for every pair of shows.
#
# for instance, if a NN will estimate every 2 shows as the same pair, we all agree that the NN is not doing its job, and it learns NOTHING, and the acc on balanced data will be about 50%.
# But if we will take a test_data that contains 80% of shows that come from the same pair - we will get 80% acc! a great result for a NN that don't know anything (a model that all it's predictions atre the same).
#
# But if we will check the false positive we will see that its value is 100%
# and we will understand immediately that the NN is worthless!
# (we will need the false negative also for the exact opposite reasons.)

# %%
def get_accuracy(model, data, batch_size=50):
    """Compute the model accuracy on the data set. This function returns two
    separate values: the model accuracy on the positive samples,
    and the model accuracy on the negative samples.

    Example Usage:

    >>> model = CNN() # create untrained model
    >>> pos_acc, neg_acc= get_accuracy(model, valid_data)
    >>> false_positive = 1 - pos_acc
    >>> false_negative = 1 - neg_acc
    """

    model.eval()
    n = data.shape[0]

    data_pos = generate_same_pair(data)      # should have shape [n * 3, 448, 224, 3]
    data_neg = generate_different_pair(data) # should have shape [n * 3, 448, 224, 3]

    pos_correct = 0
    for i in range(0, len(data_pos), batch_size):
        xs = torch.Tensor(data_pos[i:i+batch_size]).transpose(1, 3)
        zs = model(xs)
        pred = zs.max(1, keepdim=True)[1] # get the index of the max logit
        pred = pred.detach().numpy()
        pos_correct += (pred == 0).sum()

    neg_correct = 0
    for i in range(0, len(data_neg), batch_size):
        xs = torch.Tensor(data_neg[i:i+batch_size]).transpose(1, 3)
        zs = model(xs)
        pred = zs.max(1, keepdim=True)[1] # get the index of the max logit
        pred = pred.detach().numpy()
        neg_correct += (pred == 1).sum()

    return pos_correct / (n * 3), neg_correct / (n * 3)

# %% [markdown]
# ## Question 3. Training (40%)
#
# Now, we will write the functions required to train the model.
#
# Although our task is a binary classification problem, we will still use the architecture
# of a multi-class classification problem. That is, we'll use a one-hot vector to represent
# our target (like we did in the previous assignment). We'll also use `CrossEntropyLoss` instead of
# `BCEWithLogitsLoss` (this is a standard practice in machine learning because
# this architecture often performs better).
#
# ### Part (a) -- 22%
#
# Write the function `train_model` that takes in (as parameters) the model, training data,
# validation data, and other hyperparameters like the batch size, weight decay, etc.
# This function should be somewhat similar to the training code that you wrote
# in Assignment 2, but with a major difference in the way we treat our training data.
#
# Since our positive (shoes of the same pair) and negative (shoes of different pairs) training sets are separate, it is actually easier for
# us to generate separate minibatches of positive and negative training data.
#  In
# each iteration, we'll take `batch_size / 2` positive samples and `batch_size / 2`
# negative samples. We will also generate labels of 1's for the positive samples,
# and 0's for the negative samples.
#
# Here is what your training function should include:
#
# - main training loop; choice of loss function; choice of optimizer
# - obtaining the positive and negative samples
# - shuffling the positive and negative samples at the start of each epoch
# - in each iteration, take `batch_size / 2` positive samples and `batch_size / 2` negative samples
#   as our input for this batch
# - in each iteration, take `np.ones(batch_size / 2)` as the labels for the positive samples, and
#   `np.zeros(batch_size / 2)` as the labels for the negative samples
# - conversion from numpy arrays to PyTorch tensors, making sure that the input has dimensions $N \times C \times H \times W$ (known as NCHW tensor), where $N$ is the number of images batch size, $C$ is the number of channels, $H$ is the height of the image, and $W$ is the width of the image.
# - computing the forward and backward passes
# - after every epoch, report the accuracies for the training set and validation set
# - track the training curve information and plot the training curve
#
# It is also recommended to checkpoint your model (save a copy) after every epoch, as we did in Assignment 2.

# %%
def train_model(model,
                training_data = train_data,
                validation_data = valid_data,
                batch_size = 50,
                learning_rate = 0.001,
                weight_decay = 0,
                max_iters = 1000,
                checkpoint_path = None):

  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters(),
                          lr=learning_rate,
                          weight_decay=weight_decay)


  same_pairs = generate_same_pair(training_data)
  different_pairs = generate_different_pair(training_data)

  iters, losses = [], []
  iters_sub, train_accs, val_accs  = [], [] ,[]

  n = 0 # iterations
  while True:
    idx_pos = np.random.permutation(same_pairs.shape[0])
    same_pairs_epoch = same_pairs[idx_pos]
    idx_neg = np.random.permutation(different_pairs.shape[0])
    different_pairs_epoch = different_pairs[idx_neg]
    for i in range(0, same_pairs.shape[0], batch_size//2):
      if (i + batch_size//2) > same_pairs.shape[0]:
        break

      same_pairs_batch = same_pairs[i:i + (batch_size//2)] 
      same_pairs_batch = torch.from_numpy(same_pairs_batch.transpose((0,3,2,1)))

      different_pairs_batch = different_pairs[i:i + (batch_size//2)] 
      different_pairs_batch = torch.from_numpy(different_pairs_batch.transpose((0,3,2,1)))

      xt = torch.cat((same_pairs_batch,different_pairs_batch))

      same_labels = np.concatenate((np.ones([batch_size // 2,1]),np.zeros([batch_size // 2 , 1])),axis=1)
      different_labels = np.concatenate((np.zeros([batch_size // 2,1]),np.ones([batch_size // 2,1])),axis = 1)
      labels = np.concatenate((same_labels,different_labels))
      st = torch.Tensor(labels).float()


      indices = np.random.permutation(st.shape[0])
      st = st[indices]
      xt = xt[indices]
      zs = model(xt.float())
      optimizer.zero_grad()
      loss = criterion(zs, st)
      loss.backward()
      optimizer.step()

      
      iters.append(n)
      losses.append(float(loss)/batch_size)

      if n % 10 == 0:
        iters_sub.append(n)
        train_cost = float(loss.detach().numpy())

        train_pos_acc, train_neg_acc = get_accuracy(model, training_data, batch_size)
        train_accs.append((train_pos_acc + train_neg_acc) / 2.0)

        val_pos_acc, val_neg_acc = get_accuracy(model, validation_data, batch_size)
        val_accs.append((val_pos_acc + val_neg_acc) / 2.0)
        print("Iter %d. [Val Acc %.0f%%] [Train Acc %.0f%%, Loss %f] val--> [neg Acc %.0f%%,pos Acc %.0f%%] train -->[neg Acc %.0f%%,pos Acc %.0f%%]" % (
              n,
              ((val_pos_acc + val_neg_acc) / 2.0) * 100,
              ((train_pos_acc + train_neg_acc) / 2.0) * 100,
              train_cost,
              val_neg_acc * 100,
              val_pos_acc * 100,
              train_neg_acc * 100,
              train_pos_acc * 100))

        if (checkpoint_path is not None) and n > 0:
            torch.save(model.state_dict(), checkpoint_path.format(n))
      n += 1

      if n > max_iters:
          return iters, losses, iters_sub, train_accs, val_accs


def plot_learning_curve(iters, losses, iters_sub, train_accs, val_accs):
    """
    Plot the learning curve.
    """
    plt.title("Learning Curve: Loss per Iteration")
    plt.plot(iters, losses, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Learning Curve: Accuracy per Iteration")
    plt.plot(iters_sub, train_accs, label="Train")
    plt.plot(iters_sub, val_accs, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# ### Part (b) -- 6%
#
# Sanity check your code from Q3(a) and from Q2(a) and Q2(b) by showing that your models
# can memorize a very small subset of the training set (e.g. 5 images).
# You should be able to achieve 90%+ accuracy (don't forget to calculate the accuracy)
# relatively quickly (within ~30 or so iterations).
#
#
# (Start with the second network, it is easier to converge)
#
# Try to find the general parameters combination that work for each network, it can help you a little bit later.

# %%
# Write your code here. Remember to include your results so that we can
# see that your model attains a high training accuracy.
print("----------------------- CNN----------------------------")

modelCNN = CNN()
dataCNN = train_model(modelCNN,
                training_data = train_data[:1],
                validation_data = valid_data[:1],
                batch_size = 6,
                learning_rate = 0.001,
                weight_decay = 0,
                max_iters = 100,
                checkpoint_path = None)

print("CNN learning curves:")
plot_learning_curve(*dataCNN)

print("----------------------- CNNchannel----------------------")
modelCNNchannel = CNNChannel()
dataCNNchannel = train_model(modelCNNchannel,
                training_data = train_data[:1],
                validation_data = valid_data[:1],
                batch_size = 6,
                learning_rate = 0.001,
                weight_decay = 0,
                max_iters = 50,
                checkpoint_path = None)

print("CNN channel learning curves:")
plot_learning_curve(*dataCNNchannel)
# Out:
# ----------------------- CNN----------------------------
# Iter 0. [Val Acc 50%] [Train Acc 50%, Loss 0.693129] val--> [neg Acc 0%,pos Acc 100%] train -->[neg Acc 0%,pos Acc 100%]
# Iter 10. [Val Acc 50%] [Train Acc 50%, Loss 0.693158] val--> [neg Acc 0%,pos Acc 100%] train -->[neg Acc 0%,pos Acc 100%]
# Iter 20. [Val Acc 50%] [Train Acc 50%, Loss 0.693143] val--> [neg Acc 100%,pos Acc 0%] train -->[neg Acc 100%,pos Acc 0%]
# Iter 30. [Val Acc 50%] [Train Acc 50%, Loss 0.693120] val--> [neg Acc 0%,pos Acc 100%] train -->[neg Acc 0%,pos Acc 100%]
# Iter 40. [Val Acc 67%] [Train Acc 67%, Loss 0.693086] val--> [neg Acc 100%,pos Acc 33%] train -->[neg Acc 67%,pos Acc 67%]
# Iter 50. [Val Acc 50%] [Train Acc 50%, Loss 0.693019] val--> [neg Acc 0%,pos Acc 100%] train -->[neg Acc 0%,pos Acc 100%]
# Iter 60. [Val Acc 50%] [Train Acc 50%, Loss 0.692821] val--> [neg Acc 0%,pos Acc 100%] train -->[neg Acc 0%,pos Acc 100%]
# Iter 70. [Val Acc 33%] [Train Acc 50%, Loss 0.692085] val--> [neg Acc 0%,pos Acc 67%] train -->[neg Acc 0%,pos Acc 100%]
# Iter 80. [Val Acc 50%] [Train Acc 83%, Loss 0.688708] val--> [neg Acc 100%,pos Acc 0%] train -->[neg Acc 100%,pos Acc 67%]
# Iter 90. [Val Acc 67%] [Train Acc 100%, Loss 0.671797] val--> [neg Acc 67%,pos Acc 67%] train -->[neg Acc 100%,pos Acc 100%]
# Iter 100. [Val Acc 67%] [Train Acc 100%, Loss 0.611375] val--> [neg Acc 100%,pos Acc 33%] train -->[neg Acc 100%,pos Acc 100%]
# CNN learning curves:
# ----------------------- CNNchannel----------------------
# Iter 0. [Val Acc 50%] [Train Acc 50%, Loss 0.693169] val--> [neg Acc 100%,pos Acc 0%] train -->[neg Acc 100%,pos Acc 0%]
# Iter 10. [Val Acc 50%] [Train Acc 50%, Loss 0.685918] val--> [neg Acc 100%,pos Acc 0%] train -->[neg Acc 100%,pos Acc 0%]
# Iter 20. [Val Acc 83%] [Train Acc 100%, Loss 0.539757] val--> [neg Acc 67%,pos Acc 100%] train -->[neg Acc 100%,pos Acc 100%]
# Iter 30. [Val Acc 100%] [Train Acc 100%, Loss 0.094011] val--> [neg Acc 100%,pos Acc 100%] train -->[neg Acc 100%,pos Acc 100%]
# Iter 40. [Val Acc 100%] [Train Acc 100%, Loss 0.000431] val--> [neg Acc 100%,pos Acc 100%] train -->[neg Acc 100%,pos Acc 100%]
# Iter 50. [Val Acc 100%] [Train Acc 100%, Loss 0.000005] val--> [neg Acc 100%,pos Acc 100%] train -->[neg Acc 100%,pos Acc 100%]
# CNN channel learning curves:

# %% [markdown]
# ### Part (c) -- 8%
#
# Train your models from Q2(a) and Q2(b). Change the values of a few
# hyperparameters, including the learning rate, batch size, choice of $n$, and
# the kernel size. You do not need to check all values for all hyperparameters. Instead, try to make big changes to see how each change affect your scores.
# (try to start with finding a resonable learning rate for each network, that start changing the other parameters, the first network might need bigger $n$ and kernel size)
#
# In this section, explain how you tuned your hyperparameters.

# %% [markdown]
# **Write your explanation here:**
#
# to get the best parameters we can get we started, as segguested, with a loop on the learning rate.
# we found out that the best learning rate was 0.001 for both NN.
# after wards we started to increase and decrease the value of n, kernel ant batch size:
#
# * best results for CNN were $μ = 0.001 (n=4, kernel=3, batch size = 32)$
# * best results for CNNChannel were $μ = 0.001 (n=5, kernel=3, batch size = 50)$
#
#
# after that, we tried to see if there a learning rate that might be better for those hyper parameters, but we didng get better results by changing the learning rate.
# the guidline was that for CNN we will allow 1200 iteration and only 500 for the CNNChannel model. also, we choose higher value for n and kernel size for the CNN model.

# %%
# mu = 0.001
# for n in [4,5,6,7]:
#   for k in [3,5]:
#     for batch in [32, 64, 90]:
#       for weight in [0, 0.0001, 0.00001]:
#         print(f'parmas -> learning_rate = {mu}, n = {n}, kernel = {k}, batch_size = {batch}, weight_decay = {weight}')
#         print('**************CNN**************')
#         a = CNN(n=n, kernel_size = k)
#         _ = train_model(a,
#                         batch_size = batch,
#                         learning_rate = mu,
#                         weight_decay = weight,
#                         max_iters = 1200)
#         print('**************CNNChannel**************')
#         b = CNNChannel(n=n, kernel_size = k)
#         _ = train_model(b,
#                         batch_size = batch,
#                         learning_rate = mu,
#                         weight_decay = weight,
#                         max_iters = 500)
        
# k_cnn = 3
# n_cnn = 4
# batch_cnn = 88
# weight_cnn = 0

# k_cnnch = 3
# n_cnnch = 4
# batch_cnnch = 88
# weight_cnnch = 0

# for mu in [0.0005, 0.001, 0.0015]:
#   print(f' mu = {mu}')
#   print('**************CNN**************')
#   a = CNN(n=n_cnn, kernel_size = k_cnn)
#   _ = train_model(a,
#                   batch_size = batch_cnn,
#                   learning_rate = mu,
#                   weight_decay = weight_cnn,
#                   max_iters = 1200)
#   print('**************CNNChannel**************')
#   b = CNNChannel(n=n_cnnch, kernel_size = k_cnnch)
#   _ = train_model(b,
#                   batch_size = batch_cnnch,
#                   learning_rate = mu,
#                   weight_decay = weight_cnnch,
#                   max_iters = 500)
# Out:
# [[0. 1.]
#  [0. 1.]
#  [1. 0.]
#  [1. 0.]]

# %%
bestCNN = CNN(n=4, kernel_size=3)
data_bestCNN = train_model(bestCNN,
                          training_data=train_data,
                          validation_data = valid_data,
                          max_iters=1000,
                          batch_size=90,
                          learning_rate=0.001,
                          weight_decay = 0,
                          checkpoint_path = "/content/gdrive/MyDrive/Data/assigment3/best_cnn/ckpt - {}.pk")
# Out:
# Iter 10. [Val Acc 50%] [Train Acc 50%, Loss 0.695010] val--> [neg Acc 0%,pos Acc 100%] train -->[neg Acc 0%,pos Acc 100%]
# Iter 20. [Val Acc 50%] [Train Acc 50%, Loss 0.693183] val--> [neg Acc 100%,pos Acc 0%] train -->[neg Acc 100%,pos Acc 0%]
# Iter 30. [Val Acc 50%] [Train Acc 50%, Loss 0.693077] val--> [neg Acc 0%,pos Acc 100%] train -->[neg Acc 0%,pos Acc 100%]
# Iter 40. [Val Acc 50%] [Train Acc 50%, Loss 0.692904] val--> [neg Acc 99%,pos Acc 1%] train -->[neg Acc 100%,pos Acc 0%]
# Iter 50. [Val Acc 49%] [Train Acc 48%, Loss 0.692686] val--> [neg Acc 29%,pos Acc 70%] train -->[neg Acc 28%,pos Acc 68%]
# Iter 60. [Val Acc 49%] [Train Acc 43%, Loss 0.692345] val--> [neg Acc 62%,pos Acc 36%] train -->[neg Acc 64%,pos Acc 22%]
# Iter 70. [Val Acc 50%] [Train Acc 50%, Loss 0.691806] val--> [neg Acc 99%,pos Acc 1%] train -->[neg Acc 100%,pos Acc 1%]
# Iter 80. [Val Acc 47%] [Train Acc 44%, Loss 0.690844] val--> [neg Acc 57%,pos Acc 38%] train -->[neg Acc 55%,pos Acc 32%]
# Iter 90. [Val Acc 48%] [Train Acc 45%, Loss 0.687408] val--> [neg Acc 48%,pos Acc 48%] train -->[neg Acc 49%,pos Acc 42%]
# Iter 100. [Val Acc 49%] [Train Acc 46%, Loss 0.670250] val--> [neg Acc 38%,pos Acc 59%] train -->[neg Acc 42%,pos Acc 49%]
# Iter 110. [Val Acc 53%] [Train Acc 52%, Loss 0.616755] val--> [neg Acc 23%,pos Acc 83%] train -->[neg Acc 34%,pos Acc 70%]
# Iter 120. [Val Acc 64%] [Train Acc 62%, Loss 0.519765] val--> [neg Acc 33%,pos Acc 96%] train -->[neg Acc 38%,pos Acc 85%]
# Iter 130. [Val Acc 67%] [Train Acc 63%, Loss 0.464238] val--> [neg Acc 39%,pos Acc 94%] train -->[neg Acc 42%,pos Acc 84%]
# Iter 140. [Val Acc 72%] [Train Acc 63%, Loss 0.384838] val--> [neg Acc 54%,pos Acc 91%] train -->[neg Acc 47%,pos Acc 79%]
# Iter 150. [Val Acc 64%] [Train Acc 68%, Loss 0.427023] val--> [neg Acc 90%,pos Acc 39%] train -->[neg Acc 96%,pos Acc 41%]
# Iter 160. [Val Acc 69%] [Train Acc 74%, Loss 0.339072] val--> [neg Acc 68%,pos Acc 70%] train -->[neg Acc 75%,pos Acc 73%]
# Iter 170. [Val Acc 75%] [Train Acc 66%, Loss 0.267687] val--> [neg Acc 61%,pos Acc 88%] train -->[neg Acc 51%,pos Acc 81%]
# Iter 180. [Val Acc 76%] [Train Acc 77%, Loss 0.185682] val--> [neg Acc 84%,pos Acc 68%] train -->[neg Acc 89%,pos Acc 65%]
# Iter 190. [Val Acc 75%] [Train Acc 77%, Loss 0.135650] val--> [neg Acc 77%,pos Acc 72%] train -->[neg Acc 87%,pos Acc 67%]
# Iter 200. [Val Acc 72%] [Train Acc 75%, Loss 0.220134] val--> [neg Acc 77%,pos Acc 68%] train -->[neg Acc 75%,pos Acc 75%]
# Iter 210. [Val Acc 74%] [Train Acc 64%, Loss 0.262019] val--> [neg Acc 70%,pos Acc 78%] train -->[neg Acc 61%,pos Acc 67%]
# Iter 220. [Val Acc 71%] [Train Acc 76%, Loss 0.215228] val--> [neg Acc 84%,pos Acc 58%] train -->[neg Acc 92%,pos Acc 60%]
# Iter 230. [Val Acc 75%] [Train Acc 67%, Loss 0.130644] val--> [neg Acc 65%,pos Acc 84%] train -->[neg Acc 52%,pos Acc 82%]
# Iter 240. [Val Acc 72%] [Train Acc 66%, Loss 0.091431] val--> [neg Acc 72%,pos Acc 71%] train -->[neg Acc 63%,pos Acc 70%]
# Iter 250. [Val Acc 75%] [Train Acc 78%, Loss 0.237563] val--> [neg Acc 77%,pos Acc 72%] train -->[neg Acc 84%,pos Acc 72%]
# Iter 260. [Val Acc 64%] [Train Acc 71%, Loss 0.273621] val--> [neg Acc 84%,pos Acc 45%] train -->[neg Acc 97%,pos Acc 45%]
# Iter 270. [Val Acc 72%] [Train Acc 64%, Loss 0.210857] val--> [neg Acc 74%,pos Acc 70%] train -->[neg Acc 63%,pos Acc 65%]
# Iter 280. [Val Acc 68%] [Train Acc 67%, Loss 0.115228] val--> [neg Acc 72%,pos Acc 64%] train -->[neg Acc 64%,pos Acc 70%]
# Iter 290. [Val Acc 75%] [Train Acc 78%, Loss 0.089643] val--> [neg Acc 84%,pos Acc 65%] train -->[neg Acc 97%,pos Acc 59%]
# Iter 300. [Val Acc 75%] [Train Acc 79%, Loss 0.033275] val--> [neg Acc 80%,pos Acc 70%] train -->[neg Acc 93%,pos Acc 66%]
# Iter 310. [Val Acc 67%] [Train Acc 71%, Loss 0.026185] val--> [neg Acc 65%,pos Acc 70%] train -->[neg Acc 61%,pos Acc 80%]
# Iter 320. [Val Acc 75%] [Train Acc 79%, Loss 0.036773] val--> [neg Acc 77%,pos Acc 72%] train -->[neg Acc 91%,pos Acc 67%]
# Iter 330. [Val Acc 73%] [Train Acc 79%, Loss 0.044881] val--> [neg Acc 83%,pos Acc 64%] train -->[neg Acc 96%,pos Acc 63%]
# Iter 340. [Val Acc 70%] [Train Acc 78%, Loss 0.024894] val--> [neg Acc 78%,pos Acc 61%] train -->[neg Acc 91%,pos Acc 66%]
# Iter 350. [Val Acc 68%] [Train Acc 79%, Loss 0.020438] val--> [neg Acc 80%,pos Acc 57%] train -->[neg Acc 94%,pos Acc 64%]
# Iter 360. [Val Acc 59%] [Train Acc 71%, Loss 0.013303] val--> [neg Acc 57%,pos Acc 61%] train -->[neg Acc 62%,pos Acc 80%]
# Iter 370. [Val Acc 63%] [Train Acc 71%, Loss 0.014559] val--> [neg Acc 68%,pos Acc 58%] train -->[neg Acc 63%,pos Acc 79%]
# Iter 380. [Val Acc 65%] [Train Acc 72%, Loss 0.007447] val--> [neg Acc 65%,pos Acc 65%] train -->[neg Acc 59%,pos Acc 84%]
# Iter 390. [Val Acc 68%] [Train Acc 79%, Loss 0.010970] val--> [neg Acc 81%,pos Acc 55%] train -->[neg Acc 96%,pos Acc 61%]
# Iter 400. [Val Acc 67%] [Train Acc 70%, Loss 0.008631] val--> [neg Acc 65%,pos Acc 68%] train -->[neg Acc 61%,pos Acc 80%]
# Iter 410. [Val Acc 67%] [Train Acc 80%, Loss 0.007719] val--> [neg Acc 78%,pos Acc 57%] train -->[neg Acc 96%,pos Acc 64%]
# Iter 420. [Val Acc 63%] [Train Acc 71%, Loss 0.003394] val--> [neg Acc 65%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 80%]
# Iter 430. [Val Acc 63%] [Train Acc 70%, Loss 0.002217] val--> [neg Acc 67%,pos Acc 59%] train -->[neg Acc 63%,pos Acc 78%]
# Iter 440. [Val Acc 62%] [Train Acc 70%, Loss 0.024016] val--> [neg Acc 65%,pos Acc 59%] train -->[neg Acc 62%,pos Acc 77%]
# Iter 450. [Val Acc 68%] [Train Acc 81%, Loss 0.037319] val--> [neg Acc 77%,pos Acc 59%] train -->[neg Acc 94%,pos Acc 67%]
# Iter 460. [Val Acc 63%] [Train Acc 68%, Loss 0.154297] val--> [neg Acc 62%,pos Acc 64%] train -->[neg Acc 51%,pos Acc 85%]
# Iter 470. [Val Acc 64%] [Train Acc 72%, Loss 0.621092] val--> [neg Acc 83%,pos Acc 45%] train -->[neg Acc 95%,pos Acc 49%]
# Iter 480. [Val Acc 68%] [Train Acc 72%, Loss 0.298868] val--> [neg Acc 78%,pos Acc 58%] train -->[neg Acc 86%,pos Acc 58%]
# Iter 490. [Val Acc 67%] [Train Acc 69%, Loss 0.148462] val--> [neg Acc 68%,pos Acc 65%] train -->[neg Acc 61%,pos Acc 76%]
# Iter 500. [Val Acc 67%] [Train Acc 70%, Loss 0.058153] val--> [neg Acc 68%,pos Acc 65%] train -->[neg Acc 61%,pos Acc 79%]
# Iter 510. [Val Acc 70%] [Train Acc 80%, Loss 0.026491] val--> [neg Acc 78%,pos Acc 62%] train -->[neg Acc 96%,pos Acc 65%]
# Iter 520. [Val Acc 71%] [Train Acc 80%, Loss 0.012793] val--> [neg Acc 74%,pos Acc 68%] train -->[neg Acc 93%,pos Acc 68%]
# Iter 530. [Val Acc 63%] [Train Acc 70%, Loss 0.020110] val--> [neg Acc 65%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 78%]
# Iter 540. [Val Acc 63%] [Train Acc 72%, Loss 0.008611] val--> [neg Acc 65%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 81%]
# Iter 550. [Val Acc 69%] [Train Acc 81%, Loss 0.002810] val--> [neg Acc 77%,pos Acc 61%] train -->[neg Acc 96%,pos Acc 66%]
# Iter 560. [Val Acc 63%] [Train Acc 72%, Loss 0.003804] val--> [neg Acc 65%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 81%]
# Iter 570. [Val Acc 64%] [Train Acc 72%, Loss 0.002022] val--> [neg Acc 65%,pos Acc 62%] train -->[neg Acc 62%,pos Acc 81%]
# Iter 580. [Val Acc 64%] [Train Acc 71%, Loss 0.015563] val--> [neg Acc 65%,pos Acc 62%] train -->[neg Acc 62%,pos Acc 81%]
# Iter 590. [Val Acc 66%] [Train Acc 79%, Loss 0.019769] val--> [neg Acc 81%,pos Acc 51%] train -->[neg Acc 97%,pos Acc 61%]
# Iter 600. [Val Acc 66%] [Train Acc 79%, Loss 0.015161] val--> [neg Acc 83%,pos Acc 49%] train -->[neg Acc 97%,pos Acc 61%]
# Iter 610. [Val Acc 67%] [Train Acc 80%, Loss 0.010820] val--> [neg Acc 78%,pos Acc 57%] train -->[neg Acc 96%,pos Acc 63%]
# Iter 620. [Val Acc 60%] [Train Acc 71%, Loss 0.004746] val--> [neg Acc 67%,pos Acc 54%] train -->[neg Acc 64%,pos Acc 78%]
# Iter 630. [Val Acc 65%] [Train Acc 80%, Loss 0.003691] val--> [neg Acc 78%,pos Acc 52%] train -->[neg Acc 97%,pos Acc 64%]
# Iter 640. [Val Acc 67%] [Train Acc 81%, Loss 0.000914] val--> [neg Acc 77%,pos Acc 58%] train -->[neg Acc 96%,pos Acc 66%]
# Iter 650. [Val Acc 64%] [Train Acc 71%, Loss 0.000603] val--> [neg Acc 65%,pos Acc 62%] train -->[neg Acc 63%,pos Acc 80%]
# Iter 660. [Val Acc 69%] [Train Acc 81%, Loss 0.000624] val--> [neg Acc 77%,pos Acc 61%] train -->[neg Acc 96%,pos Acc 66%]
# Iter 670. [Val Acc 63%] [Train Acc 72%, Loss 0.000389] val--> [neg Acc 65%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 81%]
# Iter 680. [Val Acc 68%] [Train Acc 81%, Loss 0.000365] val--> [neg Acc 77%,pos Acc 59%] train -->[neg Acc 96%,pos Acc 65%]
# Iter 690. [Val Acc 63%] [Train Acc 71%, Loss 0.000259] val--> [neg Acc 65%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 79%]
# Iter 700. [Val Acc 69%] [Train Acc 81%, Loss 0.000236] val--> [neg Acc 77%,pos Acc 61%] train -->[neg Acc 96%,pos Acc 65%]
# Iter 710. [Val Acc 63%] [Train Acc 71%, Loss 0.000206] val--> [neg Acc 65%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 78%]
# Iter 720. [Val Acc 69%] [Train Acc 81%, Loss 0.000184] val--> [neg Acc 77%,pos Acc 61%] train -->[neg Acc 96%,pos Acc 66%]
# Iter 730. [Val Acc 64%] [Train Acc 72%, Loss 0.000165] val--> [neg Acc 65%,pos Acc 62%] train -->[neg Acc 63%,pos Acc 80%]
# Iter 740. [Val Acc 64%] [Train Acc 72%, Loss 0.000150] val--> [neg Acc 65%,pos Acc 62%] train -->[neg Acc 63%,pos Acc 81%]
# Iter 750. [Val Acc 70%] [Train Acc 81%, Loss 0.000136] val--> [neg Acc 77%,pos Acc 62%] train -->[neg Acc 96%,pos Acc 66%]
# Iter 760. [Val Acc 64%] [Train Acc 72%, Loss 0.000123] val--> [neg Acc 65%,pos Acc 62%] train -->[neg Acc 63%,pos Acc 80%]
# Iter 770. [Val Acc 70%] [Train Acc 81%, Loss 0.000112] val--> [neg Acc 77%,pos Acc 62%] train -->[neg Acc 96%,pos Acc 66%]
# Iter 780. [Val Acc 64%] [Train Acc 71%, Loss 0.000105] val--> [neg Acc 65%,pos Acc 62%] train -->[neg Acc 63%,pos Acc 78%]
# Iter 790. [Val Acc 64%] [Train Acc 70%, Loss 0.000098] val--> [neg Acc 65%,pos Acc 62%] train -->[neg Acc 63%,pos Acc 76%]
# Iter 800. [Val Acc 70%] [Train Acc 81%, Loss 0.000090] val--> [neg Acc 77%,pos Acc 62%] train -->[neg Acc 96%,pos Acc 66%]
# Iter 810. [Val Acc 64%] [Train Acc 72%, Loss 0.000084] val--> [neg Acc 65%,pos Acc 62%] train -->[neg Acc 63%,pos Acc 80%]
# Iter 820. [Val Acc 70%] [Train Acc 81%, Loss 0.000077] val--> [neg Acc 77%,pos Acc 62%] train -->[neg Acc 96%,pos Acc 65%]
# Iter 830. [Val Acc 63%] [Train Acc 72%, Loss 0.000074] val--> [neg Acc 65%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 80%]
# Iter 840. [Val Acc 69%] [Train Acc 81%, Loss 0.000068] val--> [neg Acc 77%,pos Acc 61%] train -->[neg Acc 96%,pos Acc 66%]
# Iter 850. [Val Acc 63%] [Train Acc 72%, Loss 0.000063] val--> [neg Acc 65%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 81%]
# Iter 860. [Val Acc 70%] [Train Acc 81%, Loss 0.000060] val--> [neg Acc 78%,pos Acc 61%] train -->[neg Acc 96%,pos Acc 65%]
# Iter 870. [Val Acc 64%] [Train Acc 71%, Loss 0.000057] val--> [neg Acc 67%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 79%]
# Iter 880. [Val Acc 54%] [Train Acc 71%, Loss 0.000053] val--> [neg Acc 46%,pos Acc 61%] train -->[neg Acc 63%,pos Acc 79%]
# Iter 890. [Val Acc 70%] [Train Acc 81%, Loss 0.000051] val--> [neg Acc 78%,pos Acc 61%] train -->[neg Acc 96%,pos Acc 65%]
# Iter 900. [Val Acc 63%] [Train Acc 70%, Loss 0.000048] val--> [neg Acc 67%,pos Acc 59%] train -->[neg Acc 63%,pos Acc 78%]
# Iter 910. [Val Acc 63%] [Train Acc 70%, Loss 0.000045] val--> [neg Acc 67%,pos Acc 59%] train -->[neg Acc 63%,pos Acc 77%]
# Iter 920. [Val Acc 69%] [Train Acc 81%, Loss 0.000043] val--> [neg Acc 78%,pos Acc 59%] train -->[neg Acc 97%,pos Acc 66%]
# Iter 930. [Val Acc 63%] [Train Acc 72%, Loss 0.000041] val--> [neg Acc 67%,pos Acc 59%] train -->[neg Acc 63%,pos Acc 80%]
# Iter 940. [Val Acc 69%] [Train Acc 81%, Loss 0.000039] val--> [neg Acc 78%,pos Acc 59%] train -->[neg Acc 96%,pos Acc 66%]
# Iter 950. [Val Acc 63%] [Train Acc 71%, Loss 0.000038] val--> [neg Acc 67%,pos Acc 59%] train -->[neg Acc 64%,pos Acc 79%]
# Iter 960. [Val Acc 69%] [Train Acc 81%, Loss 0.000035] val--> [neg Acc 78%,pos Acc 59%] train -->[neg Acc 96%,pos Acc 65%]
# Iter 970. [Val Acc 63%] [Train Acc 71%, Loss 0.000034] val--> [neg Acc 67%,pos Acc 59%] train -->[neg Acc 64%,pos Acc 78%]
# Iter 980. [Val Acc 63%] [Train Acc 71%, Loss 0.000032] val--> [neg Acc 67%,pos Acc 59%] train -->[neg Acc 64%,pos Acc 78%]
# Iter 990. [Val Acc 69%] [Train Acc 81%, Loss 0.000030] val--> [neg Acc 78%,pos Acc 59%] train -->[neg Acc 97%,pos Acc 66%]
# Iter 1000. [Val Acc 63%] [Train Acc 71%, Loss 0.000029] val--> [neg Acc 67%,pos Acc 59%] train -->[neg Acc 64%,pos Acc 78%]

# %%
bestCNNchannel = CNNChannel(n=4,kernel_size=3)
data_bestCNNchannel = train_model(bestCNNchannel,
                                  training_data=train_data,
                                  validation_data = valid_data,
                                  max_iters=750,
                                  batch_size=32,
                                  learning_rate=0.001,
                                  weight_decay = 0,
                                  checkpoint_path = "/content/gdrive/MyDrive/Data/assigment3/best_cnn_channel/ckpt - {}.pk")
# Out:
# Iter 0. [Val Acc 50%] [Train Acc 50%, Loss 0.695115] val--> [neg Acc 100%,pos Acc 0%] train -->[neg Acc 100%,pos Acc 0%]
# Iter 10. [Val Acc 50%] [Train Acc 50%, Loss 0.691492] val--> [neg Acc 100%,pos Acc 0%] train -->[neg Acc 100%,pos Acc 0%]
# Iter 20. [Val Acc 62%] [Train Acc 49%, Loss 0.651479] val--> [neg Acc 62%,pos Acc 61%] train -->[neg Acc 50%,pos Acc 47%]
# Iter 30. [Val Acc 70%] [Train Acc 57%, Loss 0.595098] val--> [neg Acc 58%,pos Acc 81%] train -->[neg Acc 43%,pos Acc 70%]
# Iter 40. [Val Acc 69%] [Train Acc 57%, Loss 0.545796] val--> [neg Acc 58%,pos Acc 80%] train -->[neg Acc 45%,pos Acc 70%]
# Iter 50. [Val Acc 72%] [Train Acc 60%, Loss 0.485566] val--> [neg Acc 52%,pos Acc 91%] train -->[neg Acc 46%,pos Acc 75%]
# Iter 60. [Val Acc 74%] [Train Acc 74%, Loss 0.424726] val--> [neg Acc 87%,pos Acc 61%] train -->[neg Acc 82%,pos Acc 66%]
# Iter 70. [Val Acc 74%] [Train Acc 73%, Loss 0.355962] val--> [neg Acc 93%,pos Acc 55%] train -->[neg Acc 91%,pos Acc 54%]
# Iter 80. [Val Acc 75%] [Train Acc 64%, Loss 0.315389] val--> [neg Acc 54%,pos Acc 97%] train -->[neg Acc 50%,pos Acc 78%]
# Iter 90. [Val Acc 76%] [Train Acc 77%, Loss 0.275959] val--> [neg Acc 90%,pos Acc 62%] train -->[neg Acc 91%,pos Acc 64%]
# Iter 100. [Val Acc 76%] [Train Acc 77%, Loss 0.252319] val--> [neg Acc 88%,pos Acc 64%] train -->[neg Acc 90%,pos Acc 64%]
# Iter 110. [Val Acc 76%] [Train Acc 66%, Loss 0.213801] val--> [neg Acc 54%,pos Acc 99%] train -->[neg Acc 53%,pos Acc 79%]
# Iter 120. [Val Acc 75%] [Train Acc 67%, Loss 0.247376] val--> [neg Acc 54%,pos Acc 96%] train -->[neg Acc 60%,pos Acc 74%]
# Iter 130. [Val Acc 74%] [Train Acc 78%, Loss 0.174819] val--> [neg Acc 91%,pos Acc 57%] train -->[neg Acc 96%,pos Acc 61%]
# Iter 140. [Val Acc 75%] [Train Acc 68%, Loss 0.143946] val--> [neg Acc 54%,pos Acc 97%] train -->[neg Acc 58%,pos Acc 78%]
# Iter 150. [Val Acc 75%] [Train Acc 80%, Loss 0.128242] val--> [neg Acc 90%,pos Acc 59%] train -->[neg Acc 96%,pos Acc 64%]
# Iter 160. [Val Acc 75%] [Train Acc 70%, Loss 0.108870] val--> [neg Acc 55%,pos Acc 94%] train -->[neg Acc 62%,pos Acc 78%]
# Iter 170. [Val Acc 75%] [Train Acc 81%, Loss 0.096323] val--> [neg Acc 86%,pos Acc 64%] train -->[neg Acc 96%,pos Acc 66%]
# Iter 180. [Val Acc 75%] [Train Acc 81%, Loss 0.071350] val--> [neg Acc 88%,pos Acc 61%] train -->[neg Acc 97%,pos Acc 64%]
# Iter 190. [Val Acc 76%] [Train Acc 72%, Loss 0.076541] val--> [neg Acc 57%,pos Acc 96%] train -->[neg Acc 63%,pos Acc 80%]
# Iter 200. [Val Acc 68%] [Train Acc 67%, Loss 0.059160] val--> [neg Acc 39%,pos Acc 97%] train -->[neg Acc 51%,pos Acc 83%]
# Iter 210. [Val Acc 69%] [Train Acc 67%, Loss 0.116070] val--> [neg Acc 61%,pos Acc 77%] train -->[neg Acc 66%,pos Acc 68%]
# Iter 220. [Val Acc 71%] [Train Acc 81%, Loss 0.116751] val--> [neg Acc 90%,pos Acc 52%] train -->[neg Acc 99%,pos Acc 63%]
# Iter 230. [Val Acc 70%] [Train Acc 71%, Loss 0.125033] val--> [neg Acc 57%,pos Acc 84%] train -->[neg Acc 66%,pos Acc 75%]
# Iter 240. [Val Acc 71%] [Train Acc 81%, Loss 0.155316] val--> [neg Acc 87%,pos Acc 55%] train -->[neg Acc 99%,pos Acc 63%]
# Iter 250. [Val Acc 71%] [Train Acc 69%, Loss 0.171251] val--> [neg Acc 62%,pos Acc 80%] train -->[neg Acc 67%,pos Acc 72%]
# Iter 260. [Val Acc 70%] [Train Acc 80%, Loss 0.277822] val--> [neg Acc 94%,pos Acc 45%] train -->[neg Acc 100%,pos Acc 60%]
# Iter 270. [Val Acc 66%] [Train Acc 76%, Loss 0.364669] val--> [neg Acc 94%,pos Acc 38%] train -->[neg Acc 100%,pos Acc 52%]
# Iter 280. [Val Acc 67%] [Train Acc 77%, Loss 0.121051] val--> [neg Acc 94%,pos Acc 39%] train -->[neg Acc 100%,pos Acc 54%]
# Iter 290. [Val Acc 72%] [Train Acc 81%, Loss 0.057446] val--> [neg Acc 78%,pos Acc 65%] train -->[neg Acc 96%,pos Acc 67%]
# Iter 300. [Val Acc 72%] [Train Acc 71%, Loss 0.054321] val--> [neg Acc 52%,pos Acc 91%] train -->[neg Acc 66%,pos Acc 75%]
# Iter 310. [Val Acc 74%] [Train Acc 82%, Loss 0.023686] val--> [neg Acc 86%,pos Acc 62%] train -->[neg Acc 99%,pos Acc 65%]
# Iter 320. [Val Acc 74%] [Train Acc 82%, Loss 0.022533] val--> [neg Acc 86%,pos Acc 62%] train -->[neg Acc 98%,pos Acc 66%]
# Iter 330. [Val Acc 74%] [Train Acc 71%, Loss 0.016206] val--> [neg Acc 55%,pos Acc 93%] train -->[neg Acc 65%,pos Acc 77%]
# Iter 340. [Val Acc 72%] [Train Acc 82%, Loss 0.013526] val--> [neg Acc 84%,pos Acc 61%] train -->[neg Acc 98%,pos Acc 66%]
# Iter 350. [Val Acc 75%] [Train Acc 71%, Loss 0.011400] val--> [neg Acc 57%,pos Acc 94%] train -->[neg Acc 65%,pos Acc 77%]
# Iter 360. [Val Acc 74%] [Train Acc 72%, Loss 0.009877] val--> [neg Acc 55%,pos Acc 93%] train -->[neg Acc 66%,pos Acc 78%]
# Iter 370. [Val Acc 74%] [Train Acc 71%, Loss 0.008676] val--> [neg Acc 55%,pos Acc 93%] train -->[neg Acc 66%,pos Acc 77%]
# Iter 380. [Val Acc 75%] [Train Acc 72%, Loss 0.007718] val--> [neg Acc 55%,pos Acc 94%] train -->[neg Acc 66%,pos Acc 78%]
# Iter 390. [Val Acc 75%] [Train Acc 71%, Loss 0.006872] val--> [neg Acc 55%,pos Acc 94%] train -->[neg Acc 66%,pos Acc 77%]
# Iter 400. [Val Acc 75%] [Train Acc 72%, Loss 0.006191] val--> [neg Acc 55%,pos Acc 94%] train -->[neg Acc 66%,pos Acc 78%]
# Iter 410. [Val Acc 75%] [Train Acc 73%, Loss 0.005733] val--> [neg Acc 55%,pos Acc 94%] train -->[neg Acc 66%,pos Acc 80%]
# Iter 420. [Val Acc 75%] [Train Acc 72%, Loss 0.005121] val--> [neg Acc 55%,pos Acc 94%] train -->[neg Acc 66%,pos Acc 79%]
# Iter 430. [Val Acc 72%] [Train Acc 82%, Loss 0.005120] val--> [neg Acc 83%,pos Acc 62%] train -->[neg Acc 99%,pos Acc 66%]
# Iter 440. [Val Acc 72%] [Train Acc 83%, Loss 0.004631] val--> [neg Acc 83%,pos Acc 62%] train -->[neg Acc 99%,pos Acc 66%]
# Iter 450. [Val Acc 74%] [Train Acc 72%, Loss 0.004175] val--> [neg Acc 54%,pos Acc 94%] train -->[neg Acc 65%,pos Acc 78%]
# Iter 460. [Val Acc 74%] [Train Acc 72%, Loss 0.003946] val--> [neg Acc 54%,pos Acc 94%] train -->[neg Acc 66%,pos Acc 78%]
# Iter 470. [Val Acc 73%] [Train Acc 83%, Loss 0.003637] val--> [neg Acc 83%,pos Acc 64%] train -->[neg Acc 99%,pos Acc 66%]
# Iter 480. [Val Acc 73%] [Train Acc 83%, Loss 0.003356] val--> [neg Acc 83%,pos Acc 64%] train -->[neg Acc 98%,pos Acc 67%]
# Iter 490. [Val Acc 73%] [Train Acc 83%, Loss 0.003189] val--> [neg Acc 83%,pos Acc 64%] train -->[neg Acc 99%,pos Acc 67%]
# Iter 500. [Val Acc 73%] [Train Acc 83%, Loss 0.002938] val--> [neg Acc 83%,pos Acc 64%] train -->[neg Acc 99%,pos Acc 67%]
# Iter 510. [Val Acc 73%] [Train Acc 82%, Loss 0.002823] val--> [neg Acc 83%,pos Acc 64%] train -->[neg Acc 99%,pos Acc 66%]
# Iter 520. [Val Acc 73%] [Train Acc 82%, Loss 0.002668] val--> [neg Acc 83%,pos Acc 64%] train -->[neg Acc 99%,pos Acc 66%]
# Iter 530. [Val Acc 74%] [Train Acc 82%, Loss 0.002299] val--> [neg Acc 83%,pos Acc 65%] train -->[neg Acc 98%,pos Acc 67%]
# Iter 540. [Val Acc 74%] [Train Acc 83%, Loss 0.002214] val--> [neg Acc 83%,pos Acc 65%] train -->[neg Acc 98%,pos Acc 68%]
# Iter 550. [Val Acc 74%] [Train Acc 82%, Loss 0.002064] val--> [neg Acc 83%,pos Acc 65%] train -->[neg Acc 98%,pos Acc 66%]
# Iter 560. [Val Acc 73%] [Train Acc 82%, Loss 0.002062] val--> [neg Acc 84%,pos Acc 62%] train -->[neg Acc 99%,pos Acc 66%]
# Iter 570. [Val Acc 74%] [Train Acc 82%, Loss 0.001831] val--> [neg Acc 83%,pos Acc 65%] train -->[neg Acc 98%,pos Acc 67%]
# Iter 580. [Val Acc 72%] [Train Acc 82%, Loss 0.002048] val--> [neg Acc 83%,pos Acc 62%] train -->[neg Acc 98%,pos Acc 66%]
# Iter 590. [Val Acc 74%] [Train Acc 72%, Loss 0.002015] val--> [neg Acc 54%,pos Acc 94%] train -->[neg Acc 65%,pos Acc 79%]
# Iter 600. [Val Acc 74%] [Train Acc 71%, Loss 0.001786] val--> [neg Acc 54%,pos Acc 94%] train -->[neg Acc 64%,pos Acc 78%]
# Iter 610. [Val Acc 75%] [Train Acc 71%, Loss 0.002054] val--> [neg Acc 54%,pos Acc 96%] train -->[neg Acc 65%,pos Acc 77%]
# Iter 620. [Val Acc 73%] [Train Acc 82%, Loss 0.001738] val--> [neg Acc 81%,pos Acc 65%] train -->[neg Acc 98%,pos Acc 66%]
# Iter 630. [Val Acc 73%] [Train Acc 83%, Loss 0.001576] val--> [neg Acc 81%,pos Acc 65%] train -->[neg Acc 98%,pos Acc 67%]
# Iter 640. [Val Acc 75%] [Train Acc 72%, Loss 0.001530] val--> [neg Acc 54%,pos Acc 96%] train -->[neg Acc 65%,pos Acc 78%]
# Iter 650. [Val Acc 75%] [Train Acc 71%, Loss 0.001349] val--> [neg Acc 54%,pos Acc 96%] train -->[neg Acc 65%,pos Acc 78%]
# Iter 660. [Val Acc 75%] [Train Acc 72%, Loss 0.001299] val--> [neg Acc 54%,pos Acc 96%] train -->[neg Acc 65%,pos Acc 79%]
# Iter 670. [Val Acc 75%] [Train Acc 71%, Loss 0.001231] val--> [neg Acc 54%,pos Acc 96%] train -->[neg Acc 65%,pos Acc 77%]
# Iter 680. [Val Acc 75%] [Train Acc 82%, Loss 0.001172] val--> [neg Acc 81%,pos Acc 68%] train -->[neg Acc 98%,pos Acc 66%]
# Iter 690. [Val Acc 73%] [Train Acc 82%, Loss 0.001147] val--> [neg Acc 81%,pos Acc 65%] train -->[neg Acc 97%,pos Acc 67%]
# Iter 700. [Val Acc 75%] [Train Acc 82%, Loss 0.001084] val--> [neg Acc 81%,pos Acc 70%] train -->[neg Acc 98%,pos Acc 67%]
# Iter 710. [Val Acc 72%] [Train Acc 72%, Loss 0.001045] val--> [neg Acc 54%,pos Acc 90%] train -->[neg Acc 65%,pos Acc 79%]
# Iter 720. [Val Acc 74%] [Train Acc 72%, Loss 0.001020] val--> [neg Acc 54%,pos Acc 94%] train -->[neg Acc 65%,pos Acc 78%]
# Iter 730. [Val Acc 75%] [Train Acc 71%, Loss 0.000978] val--> [neg Acc 54%,pos Acc 96%] train -->[neg Acc 65%,pos Acc 77%]
# Iter 740. [Val Acc 75%] [Train Acc 71%, Loss 0.000937] val--> [neg Acc 54%,pos Acc 96%] train -->[neg Acc 65%,pos Acc 77%]
# Iter 750. [Val Acc 73%] [Train Acc 82%, Loss 0.000914] val--> [neg Acc 81%,pos Acc 65%] train -->[neg Acc 98%,pos Acc 67%]

# %% [markdown]
# ### Part (d) -- 4%
#
# Include your training curves for the **best** models from each of Q2(a) and Q2(b).
# These are the models that you will use in Question 4.

# %%
print("CNN learning curves:\n")
plot_learning_curve(*data_bestCNN)

print("CNN channel learning curves:\n")
plot_learning_curve(*data_bestCNNchannel)
# Out:
# CNN learning curves:
# CNN channel learning curves:

# %% [markdown]
# ## Question 4. Testing (15%)
#
# ### Part (a) -- 7%
#
# Report the test accuracies of your **single best** model,
# separately for the two test sets.
# Do this by choosing the  model
# architecture that produces the best validation accuracy. For instance,
# if your model attained the
# best validation accuracy in epoch 12, then the weights at epoch 12 is what you should be using
# to report the test accuracy.

# %%
# testing in which epoch we get the best valid acc:
bestCNNchannel1 = CNNChannel()
bestCNNchannel1.load_state_dict(torch.load("/content/gdrive/MyDrive/Data/assigment3/best_cnn_channel/ckpt - 750.pk"))
bestCNN1 = CNN()
bestCNN1.load_state_dict(torch.load("/content/gdrive/MyDrive/Data/assigment3/best_cnn/ckpt - 240.pk"))
# Out:
# <All keys matched successfully>

# %%
pos_acc_NNch_m,neg_acc_NNch_m = get_accuracy(bestCNNchannel1, test_m, batch_size=64)
pos_acc_NNch_w,neg_acc_NNch_w = get_accuracy(bestCNNchannel1, test_w, batch_size=64)

print("positive acc for CNNchannel for males: ",pos_acc_NNch_m *100,"%")
print("negative acc for CNNchannel for males: ",neg_acc_NNch_m*100,"%")
print("positive acc for CNNchannel for females: ",pos_acc_NNch_w*100,"%")
print("negative acc for CNNchannel for females: ",neg_acc_NNch_w*100,"%")
print('***************************************************')

pos_acc_NN_m,neg_acc_NN_m = get_accuracy(bestCNN1, test_m, batch_size=90)
pos_acc_NN_w,neg_acc_NN_w = get_accuracy(bestCNN1, test_w, batch_size=90)

print("positive acc for CNN for males: ",pos_acc_NN_m *100,"%")
print("negative acc for CNN for males: ",neg_acc_NN_m*100,"%")
print("positive acc for CNN for females: ",pos_acc_NN_w*100,"%")
print("negative acc for CNN for females: ",neg_acc_NN_w*100,"%")
# Out:
# positive acc for CNNchannel for males:  83.33333333333334 %
# negative acc for CNNchannel for males:  43.333333333333336 %
# positive acc for CNNchannel for females:  80.0 %
# negative acc for CNNchannel for females:  53.333333333333336 %
# ***************************************************
# positive acc for CNN for males:  83.33333333333334 %
# negative acc for CNN for males:  40.0 %
# positive acc for CNN for females:  86.66666666666667 %
# negative acc for CNN for females:  46.666666666666664 %

# %% [markdown]
# ### Part (b) -- 4%
#
# Display one set of men's shoes that your model correctly classified as being
# from the same pair.
#
# If your test accuracy was not 100% on the men's shoes test set,
# display one set of inputs that your model classified incorrectly.

# %%
same_pairs_images = generate_same_pair(test_m)
zs = bestCNNchannel1(torch.from_numpy(same_pairs_images.transpose((0,3,2,1))).float())
zs = torch.relu(zs).max(1, keepdim = True)[1]

for i in range(len(same_pairs_images)):
    if (zs[i] == 0):
      plt.figure()
      plt.imshow(same_pairs_images[i] + 0.5)
      plt.title("Correct detection")
      break

for i in range(len(same_pairs_images)):
    if (zs[i] == 1):
      plt.figure()
      plt.imshow(same_pairs_images[i] + 0.5)
      plt.title("Incorrect detection")
      break

# %% [markdown]
# ### Part (c) -- 4%
#
# Display one set of women's shoes that your model correctly classified as being
# from the same pair.
#
# If your test accuracy was not 100% on the women's shoes test set,
# display one set of inputs that your model classified incorrectly.

# %%
same_pairs_images = generate_same_pair(test_w)
zs = bestCNNchannel1(torch.from_numpy(same_pairs_images.transpose((0,3,2,1))).float())
# zs = torch.relu(zs).max(1, keepdim = True)[1]

zs = zs.max(1, keepdim=True)[1] # get the index of the max logit
zs = zs.detach().numpy()

for i in range(len(same_pairs_images)):
    if (zs[i] == 0):
      plt.figure()
      plt.imshow(same_pairs_images[i] + 0.5)
      plt.title("Correct detection")
      break
for i in range(len(same_pairs_images)):
    if (zs[i] == 1):
        plt.figure()
        plt.imshow(same_pairs_images[i] + 0.5)
        plt.title("Incorrect detection")
        break
